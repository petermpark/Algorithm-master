# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-64156d691fe5> in <module>
# ----> 1 import tensorflow as tf
#
# c:\users\mango\appdata\local\programs\python\python36\lib\site-packages\tensorflow\__init__.py in <module>
#      96
#      97 # We still need all the names that are toplevel on tensorflow_core
# ---> 98 from tensorflow_core import *
#      99
#     100 # These should not be visible in the main tf module.
#
# c:\users\mango\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\__init__.py in <module>
#      43 from . _api.v2 import autograph
#      44 from . _api.v2 import bitwise
# ---> 45 from . _api.v2 import compat
#      46 from . _api.v2 import config
#      47 from . _api.v2 import data
#
# c:\users\mango\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\_api\v2\compat\__init__.py in <module>
#      22
# ...
